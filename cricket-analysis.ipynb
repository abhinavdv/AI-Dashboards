# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('SuperCleaned.csv')

df.head()
# Out:
# /var/folders/9k/b_vy9rw147729qrz8n_rjjl00000gn/T/ipykernel_14511/3292448591.py:4: DtypeWarning: Columns (101,107,108,140,141,145,146,147,153,154,158,159,160) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('SuperCleaned.csv')
#    Unnamed: 0      ID              NAME  COUNTRY  \
# 0           0    8772      Henry Arkell  England
# 1           1  532565     Richard Nyren  England
# 2           2   16856  Sydney Maartensz  England
# 3           3   16715      Brian Lander  England
# 4           4   15989  Derek Kenderdine  England
#
#                         Full name   Birthdate                  Birthplace  \
# 0        Henry John Denham Arkell  1898-06-26         Edmonton, Middlesex
# 1                   Richard Nyren  1734-04-25             Eartham, Sussex
# 2  Sydney Gratien Adair Maartensz  1882-04-14             Colombo, Ceylon
# 3            Brian Richard Lander    09/01/42  Bishop Auckland, Co Durham
# ...

# %% [markdown]
# Observations:
# - What to do with empty values? Ask it to be excluded everytime a graph is made automatically?
# -

# %%
# azure_openai.py
import requests

def call_azure_openai(prompt):
    url = "https://<your-endpoint>.openai.azure.com/openai/deployments/<your-deployment>/completions?api-version=2023-05-15"
    headers = {
        "Content-Type": "application/json",
        "api-key": "<your-api-key>"
    }
    data = {
        "prompt": prompt,
        "max_tokens": 100,
        "temperature": 0,
        "model": "gpt-40"
    }
    
    response = requests.post(url, headers=headers, json=data)
    return response.json()
